# %%
from groundtruth import GENOME, GESTAO_HOSPITAL, SIA_PROJECT_25_26, LONDON_AMBULANCE_SYSTEM
GROUNDTRUTHS = [GENOME, GESTAO_HOSPITAL, LONDON_AMBULANCE_SYSTEM, SIA_PROJECT_25_26, LONDON_AMBULANCE_SYSTEM]

manual_actors = {g["name"]: g["actors"] for g in GROUNDTRUTHS}
manual_hl = {g["name"]: g["highLevelGoals"] for g in GROUNDTRUTHS}
manual_ll = {g["name"]: g["lowLevelGoals"] for g in GROUNDTRUTHS}

# %% [markdown]
# # Experiments

# %%
from threading import Thread
import sys
import os

sys.path.append('../')
from src.extraction.extractor import generate_description, generate_actors, generate_high_level_goals, generate_low_level_goals
from src.mapping.APIs_mapping import generate_mapping_apis_goals, print_api_goal_mapping
from src.self_critique.refine_response import EvalMode, generate_response_with_reflection
from src.utils import get_api_list_from_swagger
from src.examples.shot_learning import ShotPromptingMode


LLAMA_ABLATION = True
OUPUT_PATH = "output/"

os.makedirs(OUPUT_PATH, exist_ok=True)

prompting = ShotPromptingMode.ONE_SHOT
SHOTS_NUMBER = prompting

generated_actors = {}
generated_hl = {}
generated_ll = {}

def thread_for_gt(GROUNDTRUTH):
    description = generate_description(GROUNDTRUTH["link-readme"]) if "link-readme" in GROUNDTRUTH.keys() else GROUNDTRUTH["description"]

    SHOTS_NUMBER = prompting
    actors, actors_score, actors_critique = generate_response_with_reflection(
        "Actors",
        generate_actors,
        define_args=(description,),
        eval_mode=EvalMode.ACTORS,
        eval_args=(description,),
        shotPromptingMode=SHOTS_NUMBER,
        llama_ablation= LLAMA_ABLATION
    )

    generated_actors[GROUNDTRUTH["name"]] = [actor.name for actor in actors.actors]



    highLevelGoals, HL_score, HL_critique = generate_response_with_reflection(
        "High Level Goals",
        generate_high_level_goals,
        define_args=(description, actors),
        eval_mode=EvalMode.HIGH_LEVEL,
        shotPromptingMode=SHOTS_NUMBER,
        eval_args=(description, actors),
        llama_ablation= LLAMA_ABLATION
    )

    # List of high-level goals
    generated_hl[GROUNDTRUTH["name"]] = [goal.description for goal in highLevelGoals.goals]




    lowLevelGoals, LL_score, LL_critique = generate_response_with_reflection(
        "Low Level Goals",
        generate_low_level_goals,
        define_args=highLevelGoals,
        eval_mode=EvalMode.LOW_LEVEL,
        shotPromptingMode=SHOTS_NUMBER,
        eval_args=(description, actors, highLevelGoals),
        llama_ablation= LLAMA_ABLATION
    )


    # List of low-level goals
    generated_ll[GROUNDTRUTH["name"]] = [goal.description for goal in lowLevelGoals.low_level_goals]

threads = []
for GROUNDTRUTH in GROUNDTRUTHS:
    t = Thread(target=thread_for_gt, args=(GROUNDTRUTH,))
    t.start()
    threads.append(t)

for t in threads:
    t.join()


prompting_eval = prompting
LLAMA_ABLATION_EVAL = LLAMA_ABLATION
generated_actors_eval = generated_actors
generated_hl_eval = generated_hl
generated_ll_eval = generated_ll
# Out:
# Actors STARTING... (attempt 1)Actors STARTING... (attempt 1)
# No feedback provided!
#
# No feedback provided!
# Actors STARTING... (attempt 1)
# No feedback provided!
# Actors DONE...
# actors=[Actor(name='Dispatcher', description='Staff responsible for allocating ambulances to emergency calls.'), Actor(name='Ambulance Driver', description='Personnel who operate the ambulances and follow assigned routes.'), Actor(name='Radio Operator', description='Staff who communicate with ambulance drivers and coordinate dispatch operations.'), Actor(name='CAD System', description='The computer-aided dispatch system that analyzes incidents and tracks ambulance locations.')]
# High Level Goals STARTING... (attempt 1)
# No feedback provided!
# This is the provided sys prompt:  You are a helpful assistant expert in software engineering tasks.You're tasked to extract high level goals from a software description for each provided actor that is expected to interact with the software.Following the Goal-Oriented Requirements Engineering (GORE) frameworks, high-level goals are strategic objectives that define the 'why' behind a system. They are usually abstract, business-oriented, and independent of technical implementation. They represent the needs of stakeholders or the organization. Focus: Vision and justification.
# Actors DONE...
# actors=[Actor(name='Dispatcher', description='Staff responsible for allocating ambulances to emergency calls.'), Actor(name='Ambulance Driver', description='Personnel who operate the ambulances and respond to emergency calls.'), Actor(name='Radio Operator', description='Staff who communicate with ambulance drivers and manage radio communications.'), Actor(name='CAD System', description='The computer-aided dispatch system that analyzes calls and tracks ambulance locations.'), Actor(name='Emergency Caller', description='Individuals who call for ambulance services during emergencies.')]
# High Level Goals STARTING... (attempt 1)
# No feedback provided!
# This is the provided sys prompt:  You are a helpful assistant expert in software engineering tasks.You're tasked to extract high level goals from a software description for each provided actor that is expected to interact with the software.Following the Goal-Oriented Requirements Engineering (GORE) frameworks, high-level goals are strategic objectives that define the 'why' behind a system. They are usually abstract, business-oriented, and independent of technical implementation. They represent the needs of stakeholders or the organization. Focus: Vision and justification.
# Actors DONE...
# actors=[Actor(name='Citizen', description='Individuals who report issues and inconveniences in the urban environment.'), Actor(name='Municipal Operator', description='Staff members of the Municipality of Turin who review and manage citizen reports.'), Actor(name='External Maintenance Personnel', description='Workers from external companies who address specific issues reported by citizens.'), Actor(name='Administrator', description='Municipal administrators who configure the system and manage report assignments.'), Actor(name='Non-Registered User', description='Individuals who can view reports and statistics without needing to register.')]
# High Level Goals STARTING... (attempt 1)
# No feedback provided!
# This is the provided sys prompt:  You are a helpful assistant expert in software engineering tasks.You're tasked to extract high level goals from a software description for each provided actor that is expected to interact with the software.Following the Goal-Oriented Requirements Engineering (GORE) frameworks, high-level goals are strategic objectives that define the 'why' behind a system. They are usually abstract, business-oriented, and independent of technical implementation. They represent the needs of stakeholders or the organization. Focus: Vision and justification.
# High Level Goals DONE...
# goals=[HighLevelGoal(name='Efficient Ambulance Allocation', description='The dispatcher aims to allocate an available ambulance for every emergency call promptly, ensuring that response times meet the 11-minute target.', actor=Actor(name='Dispatcher', description='Staff responsible for allocating ambulances to emergency calls.')), HighLevelGoal(name='Timely Response to Emergencies', description='The ambulance driver seeks to respond to emergency calls quickly and efficiently, adhering to the standard routes and communication protocols.', actor=Actor(name='Ambulance Driver', description='Personnel who operate the ambulances and respond to emergency calls.')), HighLevelGoal(name='Effective Communication Management', description='The radio operator aims to maintain clear and accurate communication with ambulance drivers to ensure smooth operations during emergencies.', actor=Actor(name='Radio Operator', description='Staff who communicate with ambulance drivers and manage radio communications.')), HighLevelGoal(name='Accurate Incident Analysis', description='The CAD system aims to analyze incident forms effectively to ensure the correct allocation of ambulances and track their locations in real-time.', actor=Actor(name='CAD System', description='The computer-aided dispatch system that analyzes calls and tracks ambulance locations.')), HighLevelGoal(name='Quick Access to Emergency Services', description='The emergency caller seeks a reliable and quick way to access ambulance services during emergencies, ensuring their needs are met promptly.', actor=Actor(name='Emergency Caller', description='Individuals who call for ambulance services during emergencies.'))]
# Low Level Goals STARTING... (attempt 1)
# No feedback provided!
# This is the provided sys prompt:  You are a helpful assistant expert in software engineering tasks. Elicit low-level goals for a specific stakeholder in a software project. The low-level goals that you create MUST be structured to match against a set of API calls. Don't be too generic, for example, avoid goals like 'make the software fast', 'develop a web interface' etc.Each low-level goal MUST be phrased as an interaction with the system that could be implemented via an API call.Avoid generic goals. Instead, break them down into atomic actions linked to system capabilities. Following the Goal-Oriented Requirements Engineering (GORE) framework, low-level goals are technical objectives that describe 'how' the high-level goals will be achieved.
# They are more concrete and are eventually refined into specific requirements or software specifications.
# Focus: Implementation and constraints.
# High Level Goals DONE...
# goals=[HighLevelGoal(name='Efficient Ambulance Allocation', description='The dispatcher aims to allocate an available ambulance for every emergency call promptly, ensuring that response times meet the 11-minute target.', actor=Actor(name='Dispatcher', description='Staff responsible for allocating ambulances to emergency calls.')), HighLevelGoal(name='Timely Response Management', description='The ambulance driver seeks to receive clear and timely instructions to ensure they can reach the scene of an emergency within the required time frame.', actor=Actor(name='Ambulance Driver', description='Personnel who operate the ambulances and follow assigned routes.')), HighLevelGoal(name='Effective Communication', description='The radio operator aims to maintain clear and accurate communication with ambulance drivers to ensure smooth coordination during dispatch operations.', actor=Actor(name='Radio Operator', description='Staff who communicate with ambulance drivers and coordinate dispatch operations.')), HighLevelGoal(name='Accurate Incident Analysis', description='The CAD system aims to analyze incident forms efficiently to ensure that the right resources are dispatched to emergencies without delay.', actor=Actor(name='CAD System', description='The computer-aided dispatch system that analyzes incidents and tracks ambulance locations.')), HighLevelGoal(name='Real-time Location Tracking', description='The dispatcher and ambulance drivers require a reliable system to track the exact location of ambulances in real-time to optimize response times and resource allocation.', actor=Actor(name='Dispatcher', description='Staff responsible for allocating ambulances to emergency calls.')), HighLevelGoal(name='Standardized Operational Procedures', description='All actors involved seek to follow standardized routes and procedures to ensure consistency and reliability in emergency response operations.', actor=Actor(name='Ambulance Driver', description='Personnel who operate the ambulances and follow assigned routes.'))]
# Low Level Goals STARTING... (attempt 1)
# No feedback provided!
# This is the provided sys prompt:  You are a helpful assistant expert in software engineering tasks. Elicit low-level goals for a specific stakeholder in a software project. The low-level goals that you create MUST be structured to match against a set of API calls. Don't be too generic, for example, avoid goals like 'make the software fast', 'develop a web interface' etc.Each low-level goal MUST be phrased as an interaction with the system that could be implemented via an API call.Avoid generic goals. Instead, break them down into atomic actions linked to system capabilities. Following the Goal-Oriented Requirements Engineering (GORE) framework, low-level goals are technical objectives that describe 'how' the high-level goals will be achieved.
# They are more concrete and are eventually refined into specific requirements or software specifications.
# Focus: Implementation and constraints.
# High Level Goals DONE...
# goals=[HighLevelGoal(name='Enhance Citizen Engagement', description='The citizen aims to actively participate in the management of urban environments by easily reporting issues and inconveniences through the Participium system.', actor=Actor(name='Citizen', description='Individuals who report issues and inconveniences in the urban environment.')), HighLevelGoal(name='Streamline Report Management', description='The municipal operator seeks to efficiently review, manage, and respond to citizen reports to ensure timely resolution of urban issues.', actor=Actor(name='Municipal Operator', description='Staff members of the Municipality of Turin who review and manage citizen reports.')), HighLevelGoal(name='Facilitate Issue Resolution', description='The external maintenance personnel aim to receive clear and actionable reports from the Participium system to address urban issues effectively and efficiently.', actor=Actor(name='External Maintenance Personnel', description='Workers from external companies who address specific issues reported by citizens.')), HighLevelGoal(name='Optimize System Configuration', description='The administrator desires to configure the Participium system to ensure proper report assignment and management, enhancing overall operational efficiency.', actor=Actor(name='Administrator', description='Municipal administrators who configure the system and manage report assignments.')), HighLevelGoal(name='Access Information Easily', description='The non-registered user aims to view urban issue reports and statistics without the need for registration, promoting transparency and awareness in the community.', actor=Actor(name='Non-Registered User', description='Individuals who can view reports and statistics without needing to register.'))]
# Low Level Goals STARTING... (attempt 1)
# No feedback provided!
# This is the provided sys prompt:  You are a helpful assistant expert in software engineering tasks. Elicit low-level goals for a specific stakeholder in a software project. The low-level goals that you create MUST be structured to match against a set of API calls. Don't be too generic, for example, avoid goals like 'make the software fast', 'develop a web interface' etc.Each low-level goal MUST be phrased as an interaction with the system that could be implemented via an API call.Avoid generic goals. Instead, break them down into atomic actions linked to system capabilities. Following the Goal-Oriented Requirements Engineering (GORE) framework, low-level goals are technical objectives that describe 'how' the high-level goals will be achieved.
# They are more concrete and are eventually refined into specific requirements or software specifications.
# Focus: Implementation and constraints.
# Actors STARTING... (attempt 1)
# No feedback provided!
# Actors DONE...
# actors=[Actor(name='Researchers', description='Individuals conducting studies on genetic variants and their implications in cancer.'), Actor(name='Clinicians', description='Medical professionals who interpret genetic data to inform patient care and treatment decisions.'), Actor(name='Bioinformaticians', description='Specialists who analyze and interpret complex biological data, including genetic information.'), Actor(name='Software Developers', description='Engineers who develop and maintain the Genome Nexus application and its features.'), Actor(name='Data Scientists', description='Professionals who analyze genetic data to extract insights and support research.')]
# High Level Goals STARTING... (attempt 1)
# No feedback provided!
# This is the provided sys prompt:  You are a helpful assistant expert in software engineering tasks.You're tasked to extract high level goals from a software description for each provided actor that is expected to interact with the software.Following the Goal-Oriented Requirements Engineering (GORE) frameworks, high-level goals are strategic objectives that define the 'why' behind a system. They are usually abstract, business-oriented, and independent of technical implementation. They represent the needs of stakeholders or the organization. Focus: Vision and justification.
# Actors STARTING... (attempt 1)
# No feedback provided!
# Actors DONE...
# actors=[Actor(name='Hospital Administrator', description='Individuals responsible for managing hospital operations and resources.'), Actor(name='Healthcare Provider', description='Medical staff such as doctors and nurses who interact with the system to manage patient care.'), Actor(name='Patient', description='Individuals receiving medical care who may check in and out of hospitals.'), Actor(name='Supply Chain Manager', description='Personnel responsible for managing the inventory of medical supplies and ensuring availability.'), Actor(name='Public Health Official', description='Government representatives overseeing public health services and resource allocation.')]
# High Level Goals STARTING... (attempt 1)
# No feedback provided!
# This is the provided sys prompt:  You are a helpful assistant expert in software engineering tasks.You're tasked to extract high level goals from a software description for each provided actor that is expected to interact with the software.Following the Goal-Oriented Requirements Engineering (GORE) frameworks, high-level goals are strategic objectives that define the 'why' behind a system. They are usually abstract, business-oriented, and independent of technical implementation. They represent the needs of stakeholders or the organization. Focus: Vision and justification.
# High Level Goals DONE...
# goals=[HighLevelGoal(name='Facilitate Efficient Genetic Variant Analysis', description='The stakeholder aims to streamline the process of analyzing genetic variants, enabling faster and more accurate interpretations of genetic data in cancer research and treatment.', actor=Actor(name='Researchers', description='Individuals conducting studies on genetic variants and their implications in cancer.')), HighLevelGoal(name='Enhance Patient Care through Genetic Insights', description='The stakeholder seeks to utilize genetic data to inform clinical decisions, improving patient outcomes and treatment strategies based on genetic information.', actor=Actor(name='Clinicians', description='Medical professionals who interpret genetic data to inform patient care and treatment decisions.')), HighLevelGoal(name='Support Advanced Data Interpretation', description='The stakeholder desires tools and functionalities that allow for in-depth analysis and interpretation of complex genetic data, aiding in research and clinical applications.', actor=Actor(name='Bioinformaticians', description='Specialists who analyze and interpret complex biological data, including genetic information.')), HighLevelGoal(name='Ensure Robust Application Development', description='The stakeholder insists on maintaining high standards in the development and maintenance of the Genome Nexus application, ensuring it meets user needs and technical requirements.', actor=Actor(name='Software Developers', description='Engineers who develop and maintain the Genome Nexus application and its features.')), HighLevelGoal(name='Extract Actionable Insights from Genetic Data', description='The stakeholder aims to analyze genetic data effectively to derive meaningful insights that can support ongoing research and clinical practices.', actor=Actor(name='Data Scientists', description='Professionals who analyze genetic data to extract insights and support research.'))]
# Low Level Goals STARTING... (attempt 1)
# No feedback provided!
# This is the provided sys prompt:  You are a helpful assistant expert in software engineering tasks. Elicit low-level goals for a specific stakeholder in a software project. The low-level goals that you create MUST be structured to match against a set of API calls. Don't be too generic, for example, avoid goals like 'make the software fast', 'develop a web interface' etc.Each low-level goal MUST be phrased as an interaction with the system that could be implemented via an API call.Avoid generic goals. Instead, break them down into atomic actions linked to system capabilities. Following the Goal-Oriented Requirements Engineering (GORE) framework, low-level goals are technical objectives that describe 'how' the high-level goals will be achieved.
# They are more concrete and are eventually refined into specific requirements or software specifications.
# Focus: Implementation and constraints.
# Exception in thread Thread-2 (thread_for_gt):
# Traceback (most recent call last):
#   File "C:\Users\annaa\AppData\Local\Programs\Python\Python312\Lib\threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "C:\Users\annaa\AppData\Local\Programs\Python\Python312\Lib\threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\annaa\AppData\Local\Temp\ipykernel_13904\326270799.py", line 59, in thread_for_gt
#   File "C:\Users\annaa\Desktop\PhD\llm-projects\LLM_MultiAgentChain_GoalOrientedAPIAlignement\src\self_critique\refine_response.py", line 198, in generate_response_with_reflection
#     result = call_function(*define_args, feedback=feedback, mode = shotPromptingMode )
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\annaa\Desktop\PhD\llm-projects\LLM_MultiAgentChain_GoalOrientedAPIAlignement\src\extraction\extractor.py", line 178, in generate_low_level_goals
#     lowLevelGoals = generate_response(prompt, sys_prompt, LowLevelGoals)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\annaa\Desktop\PhD\llm-projects\LLM_MultiAgentChain_GoalOrientedAPIAlignement\src\llm_clients.py", line 33, in generate_response
#     response = client.beta.chat.completions.parse(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\annaa\Desktop\PhD\llm-projects\LLM_MultiAgentChain_GoalOrientedAPIAlignement\.venv_python3.12\Lib\site-packages\openai\resources\chat\completions\completions.py", line 184, in parse
#     return self._post(
#            ^^^^^^^^^^^
#   File "C:\Users\annaa\Desktop\PhD\llm-projects\LLM_MultiAgentChain_GoalOrientedAPIAlignement\.venv_python3.12\Lib\site-packages\openai\_base_client.py", line 1297, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\annaa\Desktop\PhD\llm-projects\LLM_MultiAgentChain_GoalOrientedAPIAlignement\.venv_python3.12\Lib\site-packages\openai\_base_client.py", line 1070, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-KSQgyHuFjhsjJ4oBNrdlPJgr on tokens per min (TPM): Limit 200000, Used 200000, Requested 1277. Please try again in 383ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Exception in thread Thread-3 (thread_for_gt):
# Traceback (most recent call last):
#   File "C:\Users\annaa\AppData\Local\Programs\Python\Python312\Lib\threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "C:\Users\annaa\AppData\Local\Programs\Python\Python312\Lib\threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\annaa\AppData\Local\Temp\ipykernel_13904\326270799.py", line 43, in thread_for_gt
#   File "C:\Users\annaa\Desktop\PhD\llm-projects\LLM_MultiAgentChain_GoalOrientedAPIAlignement\src\self_critique\refine_response.py", line 198, in generate_response_with_reflection
#     result = call_function(*define_args, feedback=feedback, mode = shotPromptingMode )
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\annaa\Desktop\PhD\llm-projects\LLM_MultiAgentChain_GoalOrientedAPIAlignement\src\extraction\extractor.py", line 124, in generate_high_level_goals
#     high_level_goals = generate_response(prompt, sys_prompt, HighLevelGoals)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\annaa\Desktop\PhD\llm-projects\LLM_MultiAgentChain_GoalOrientedAPIAlignement\src\llm_clients.py", line 33, in generate_response
#     response = client.beta.chat.completions.parse(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\annaa\Desktop\PhD\llm-projects\LLM_MultiAgentChain_GoalOrientedAPIAlignement\.venv_python3.12\Lib\site-packages\openai\resources\chat\completions\completions.py", line 184, in parse
#     return self._post(
#            ^^^^^^^^^^^
#   File "C:\Users\annaa\Desktop\PhD\llm-projects\LLM_MultiAgentChain_GoalOrientedAPIAlignement\.venv_python3.12\Lib\site-packages\openai\_base_client.py", line 1297, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\annaa\Desktop\PhD\llm-projects\LLM_MultiAgentChain_GoalOrientedAPIAlignement\.venv_python3.12\Lib\site-packages\openai\_base_client.py", line 1070, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-KSQgyHuFjhsjJ4oBNrdlPJgr on tokens per min (TPM): Limit 200000, Used 200000, Requested 1145. Please try again in 343ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Low Level Goals DONE...
# low_level_goals=[LowLevelGoal(name='Retrieve the list of available ambulances from the system to allocate for an emergency call.', description='The dispatcher queries the system to get the current status of all ambulances, including their availability and location.', high_level_associated=HighLevelGoal(name='Efficient Ambulance Allocation', description='The dispatcher aims to allocate an available ambulance for every emergency call promptly, ensuring that response times meet the 11-minute target.', actor=Actor(name='Dispatcher', description='Staff responsible for allocating ambulances to emergency calls.'))), LowLevelGoal(name='Select the nearest available ambulance based on the emergency call location.', description='The dispatcher uses the system to identify the closest ambulance to the incident location for quick response.', high_level_associated=HighLevelGoal(name='Efficient Ambulance Allocation', description='The dispatcher aims to allocate an available ambulance for every emergency call promptly, ensuring that response times meet the 11-minute target.', actor=Actor(name='Dispatcher', description='Staff responsible for allocating ambulances to emergency calls.'))), LowLevelGoal(name='Send allocation details to the selected ambulance driver with the incident location and instructions.', description='The dispatcher communicates the assignment to the ambulance driver through the system, including the emergency details.', high_level_associated=HighLevelGoal(name='Efficient Ambulance Allocation', description='The dispatcher aims to allocate an available ambulance for every emergency call promptly, ensuring that response times meet the 11-minute target.', actor=Actor(name='Dispatcher', description='Staff responsible for allocating ambulances to emergency calls.'))), LowLevelGoal(name='Receive and acknowledge the assignment from the dispatcher in the ambulance system.', description='The ambulance driver confirms receipt of the emergency call and allocation details through the system.', high_level_associated=HighLevelGoal(name='Timely Response Management', description='The ambulance driver seeks to receive clear and timely instructions to ensure they can reach the scene of an emergency within the required time frame.', actor=Actor(name='Ambulance Driver', description='Personnel who operate the ambulances and follow assigned routes.'))), LowLevelGoal(name='Access the route navigation system to get directions to the incident location.', description='The ambulance driver retrieves navigation instructions from the system to ensure timely arrival at the emergency scene.', high_level_associated=HighLevelGoal(name='Timely Response Management', description='The ambulance driver seeks to receive clear and timely instructions to ensure they can reach the scene of an emergency within the required time frame.', actor=Actor(name='Ambulance Driver', description='Personnel who operate the ambulances and follow assigned routes.'))), LowLevelGoal(name='Communicate with the dispatcher to report the estimated time of arrival at the incident location.', description='The ambulance driver uses the communication system to update the dispatcher on their progress and ETA.', high_level_associated=HighLevelGoal(name='Effective Communication', description='The radio operator aims to maintain clear and accurate communication with ambulance drivers to ensure smooth coordination during dispatch operations.', actor=Actor(name='Radio Operator', description='Staff who communicate with ambulance drivers and coordinate dispatch operations.'))), LowLevelGoal(name='Log the incident details and ambulance response in the CAD system for analysis.', description='The CAD system records the incident and the response actions taken for future reference and analysis.', high_level_associated=HighLevelGoal(name='Accurate Incident Analysis', description='The CAD system aims to analyze incident forms efficiently to ensure that the right resources are dispatched to emergencies wit ...
# Low Level Goals DONE...
# low_level_goals=[LowLevelGoal(name='Retrieve the list of available ambulances from the system.', description='The dispatcher requests the current status of all ambulances to identify which are available for allocation.', high_level_associated=HighLevelGoal(name='Efficient Ambulance Allocation', description='The dispatcher aims to allocate an available ambulance for every emergency call promptly, ensuring that response times meet the 11-minute target.', actor=Actor(name='Dispatcher', description='Staff responsible for allocating ambulances to emergency calls.'))), LowLevelGoal(name='Allocate an available ambulance to the emergency call.', description='The dispatcher selects an available ambulance and assigns it to the incoming emergency call.', high_level_associated=HighLevelGoal(name='Efficient Ambulance Allocation', description='The dispatcher aims to allocate an available ambulance for every emergency call promptly, ensuring that response times meet the 11-minute target.', actor=Actor(name='Dispatcher', description='Staff responsible for allocating ambulances to emergency calls.'))), LowLevelGoal(name="Update the status of the allocated ambulance to 'en route'.", description='The dispatcher changes the status of the assigned ambulance to indicate it is on its way to the emergency location.', high_level_associated=HighLevelGoal(name='Efficient Ambulance Allocation', description='The dispatcher aims to allocate an available ambulance for every emergency call promptly, ensuring that response times meet the 11-minute target.', actor=Actor(name='Dispatcher', description='Staff responsible for allocating ambulances to emergency calls.'))), LowLevelGoal(name='Receive the emergency call details including location and nature of the emergency.', description='The ambulance driver listens to the details of the emergency call provided by the dispatcher.', high_level_associated=HighLevelGoal(name='Timely Response to Emergencies', description='The ambulance driver seeks to respond to emergency calls quickly and efficiently, adhering to the standard routes and communication protocols.', actor=Actor(name='Ambulance Driver', description='Personnel who operate the ambulances and respond to emergency calls.'))), LowLevelGoal(name='Confirm receipt of the emergency call and acknowledge the details.', description='The ambulance driver confirms to the dispatcher that they have received the call and understood the details.', high_level_associated=HighLevelGoal(name='Timely Response to Emergencies', description='The ambulance driver seeks to respond to emergency calls quickly and efficiently, adhering to the standard routes and communication protocols.', actor=Actor(name='Ambulance Driver', description='Personnel who operate the ambulances and respond to emergency calls.'))), LowLevelGoal(name='Navigate to the emergency location using the provided route.', description='The ambulance driver follows the standard route to reach the emergency location as quickly as possible.', high_level_associated=HighLevelGoal(name='Timely Response to Emergencies', description='The ambulance driver seeks to respond to emergency calls quickly and efficiently, adhering to the standard routes and communication protocols.', actor=Actor(name='Ambulance Driver', description='Personnel who operate the ambulances and respond to emergency calls.'))), LowLevelGoal(name='Maintain communication with the dispatcher during transit.', description='The ambulance driver regularly updates the dispatcher on their status and any changes in the situation.', high_level_associated=HighLevelGoal(name='Timely Response to Emergencies', description='The ambulance driver seeks to respond to emergency calls quickly and efficiently, adhering to the standard routes and communication protocols.', actor=Actor(name='Ambulance Driver', description='Personnel who operate the ambulances and respond to emergency calls.'))), LowLevelGoal(name='Log the communication with the ambulance driver in the system.', ...
# Low Level Goals DONE...
# low_level_goals=[LowLevelGoal(name='Submit a new urban issue report through the Participium system', description='The citizen can fill out a form to report an issue in the urban environment, including details such as location and description.', high_level_associated=HighLevelGoal(name='Enhance Citizen Engagement', description='The citizen aims to actively participate in the management of urban environments by easily reporting issues and inconveniences through the Participium system.', actor=Actor(name='Citizen', description='Individuals who report issues and inconveniences in the urban environment.'))), LowLevelGoal(name='View the status of submitted reports in the Participium system', description='The citizen can check the current status of their previously submitted reports to stay informed about the progress.', high_level_associated=HighLevelGoal(name='Enhance Citizen Engagement', description='The citizen aims to actively participate in the management of urban environments by easily reporting issues and inconveniences through the Participium system.', actor=Actor(name='Citizen', description='Individuals who report issues and inconveniences in the urban environment.'))), LowLevelGoal(name='Receive notifications about updates on reported issues', description='The citizen can opt-in to receive alerts regarding the status changes of their reported issues via email or app notifications.', high_level_associated=HighLevelGoal(name='Enhance Citizen Engagement', description='The citizen aims to actively participate in the management of urban environments by easily reporting issues and inconveniences through the Participium system.', actor=Actor(name='Citizen', description='Individuals who report issues and inconveniences in the urban environment.'))), LowLevelGoal(name='Review and categorize incoming citizen reports', description='The municipal operator can access a dashboard to view new reports and categorize them based on urgency and type of issue.', high_level_associated=HighLevelGoal(name='Streamline Report Management', description='The municipal operator seeks to efficiently review, manage, and respond to citizen reports to ensure timely resolution of urban issues.', actor=Actor(name='Municipal Operator', description='Staff members of the Municipality of Turin who review and manage citizen reports.'))), LowLevelGoal(name='Assign reports to appropriate maintenance personnel', description='The municipal operator can assign specific reports to external maintenance personnel based on their expertise and availability.', high_level_associated=HighLevelGoal(name='Streamline Report Management', description='The municipal operator seeks to efficiently review, manage, and respond to citizen reports to ensure timely resolution of urban issues.', actor=Actor(name='Municipal Operator', description='Staff members of the Municipality of Turin who review and manage citizen reports.'))), LowLevelGoal(name='Update the status of reports after resolution', description='The municipal operator can mark reports as resolved and provide feedback on the actions taken to address the issues.', high_level_associated=HighLevelGoal(name='Streamline Report Management', description='The municipal operator seeks to efficiently review, manage, and respond to citizen reports to ensure timely resolution of urban issues.', actor=Actor(name='Municipal Operator', description='Staff members of the Municipality of Turin who review and manage citizen reports.'))), LowLevelGoal(name='Access detailed reports on urban issues for maintenance planning', description='The external maintenance personnel can view detailed reports assigned to them, including location, issue type, and urgency.', high_level_associated=HighLevelGoal(name='Facilitate Issue Resolution', description='The external maintenance personnel aim to receive clear and actionable reports from the Participium system to address urban issues effectively and efficiently.', actor=Actor(name='External Maintenance Pers ...

# %%
from src.evaluation.goal_evaluator import GoalEvaluator

PREPROCESSING = True #stop words remotion, stemming and lemmaization for the evaluation

evaluator_actors = GoalEvaluator(preprocess = False)
evaluator_hl = GoalEvaluator(preprocess = PREPROCESSING)
evaluator_ll = GoalEvaluator(preprocess = PREPROCESSING)

print("-----------------------------------------------------------")
print(f"{prompting_eval}, LLAMA ABLATION: {LLAMA_ABLATION_EVAL}, PREPROCESSING: {PREPROCESSING}")
print("-----------------------------------------------------------")

#----------------------------EVALUATION------------------------------------------------------

auc_prec_rec, best_f1 = evaluator_actors.print_prec_rec_curve(generated_actors_eval, manual_actors, output_file=f"{OUPUT_PATH}/actor_{SHOTS_NUMBER}.csv", save_to_file=True, rate_table=True)

print("Actors Precision Recall Curve AUC:", auc_prec_rec)
print(f"Best F1 Score: {best_f1}")

auc_prec_rec, best_f1 = evaluator_hl.print_prec_rec_curve(generated_hl_eval, manual_hl, output_file=f"{OUPUT_PATH}/hl_{SHOTS_NUMBER}.csv", save_to_file=True, rate_table=True)

print("High Level Precision Recall Curve AUC:", auc_prec_rec)
print(f"Best F1 Score: {best_f1}")

auc_prec_rec, best_f1 = evaluator_ll.print_prec_rec_curve(generated_ll_eval, manual_ll, output_file=f"{OUPUT_PATH}/ll_{SHOTS_NUMBER}.csv", save_to_file=True, rate_table=True)

print("Low Level Goals Precision Recall Curve AUC:", auc_prec_rec)
print(f"Best F1 Score: {best_f1}")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\annaa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\annaa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\annaa\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\annaa\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\annaa\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# MPNetModel LOAD REPORT from: sentence-transformers/all-mpnet-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# MPNetModel LOAD REPORT from: sentence-transformers/all-mpnet-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# MPNetModel LOAD REPORT from: sentence-transformers/all-mpnet-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# -----------------------------------------------------------
# ShotPromptingMode.ONE_SHOT, LLAMA ABLATION: True, PREPROCESSING: True
# -----------------------------------------------------------
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 15
#      11 print("-----------------------------------------------------------")
#      13 #----------------------------EVALUATION------------------------------------------------------
# ---> 15 auc_prec_rec, best_f1 = evaluator_actors.print_prec_rec_curve(generated_actors_eval, manual_actors, output_file=f"{OUPUT_PATH}/actor_{SHOTS_NUMBER}.csv", save_to_file=True)
#      17 print("Actors Precision Recall Curve AUC:", auc_prec_rec)
#      18 print(f"Best F1 Score: {best_f1}")
#
# File ~\Desktop\PhD\llm-projects\LLM_MultiAgentChain_GoalOrientedAPIAlignement\src\evaluation\goal_evaluator.py:217, in GoalEvaluator.print_prec_rec_curve(self, generated_goals_dict, reference_goals_dict, hide_prec_rec, save_to_file, output_file, threshold)
#     214     with open(output_file, "a") as f:
#     215         f.write(summary_str + "\n")
# --> 217 recalls = np.array([point['recall'] for point in results["rate_table"]])
#     218 precisions = np.array([point['precision'] for point in results["rate_table"]])
#     220 weighted_recalls += (recalls * weight)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
evaluator_actors.print_best_f1(generated_actors, manual_actors)
evaluator_hl.print_best_f1(generated_hl, manual_hl)
evaluator_ll.print_best_f1(generated_ll, manual_ll)

# %% [markdown]
# ### APIs Extraction from Swagger

# %%
print("API List STARTING...")
apiList = get_api_list_from_swagger(link=GROUNDTRUTH["swagger"])
print("API List DONE...")
print(apiList)

# %% [markdown]
# ### APIs Mapping to Low Level Goals

# %%
print("Mapping STARTING...")
mappings = generate_mapping_apis_goals(lowLevelGoals, apiList)
print("Mapping DONE")

# %%
print(mappings[0].low_level_goal.high_level_associated.name)

# %% [markdown]
# ### Mapping Table

# %%
import json

print_api_goal_mapping(mappings)
with open(f"{OUPUT_PATH}/final_mapping_{SHOTS_NUMBER}.csv", "w") as f:
    f.write(json.dumps(mappings, default=lambda o: o.__dict__, indent=4))

# %% [markdown]
# Merging Results from Different Ground Truth

# %%
from src.examples.shot_learning import ShotPromptingMode


import pandas as pd

def merge_csv_positional(path1, path2, w1, w2, output_path):
    # Leggi i file (usa il separatore che vedi nel file, es. ';')
    df1 = pd.read_csv(path1, sep=';')
    df2 = pd.read_csv(path2, sep=';')

    # Pulisci nomi colonne
    df1.columns = df1.columns.str.strip()
    df2.columns = df2.columns.str.strip()

    # Colonne numeriche su cui fare il calcolo
    cols_numeric = ['recall', 'fpr', 'f1_score', 'precision']

    # 1. Rimuovi eventuali spazi nelle celle
    # 2. Sostituisci virgola con punto (se usano formato italiano)
    # 3. Converti in numeri (i non-numeri diventano NaN)
    for col in cols_numeric:
        for df in [df1, df2]:
            if df[col].dtype == object:
                df[col] = df[col].astype(str).str.replace(',', '.').str.strip()
                df[col] = pd.to_numeric(df[col], errors='coerce')

    # Taglia alla lunghezza minima comune
    min_len = min(len(df1), len(df2))
    df1 = df1.iloc[:min_len].reset_index(drop=True)
    df2 = df2.iloc[:min_len].reset_index(drop=True)

    # Calcolo media pesata (gestisce i NaN se presenti)
    df_weighted = (df1[cols_numeric] * w1 + df2[cols_numeric] * w2) / (w1 + w2)

    # Ricostruisci il dataframe con 'th' del primo file
    df_result = pd.concat([df1[['th']], df_weighted], axis=1)

    # Salva
    df_result.to_csv(output_path, sep=',', index=False)
    print(f"Salvato: {output_path}")

# Esempio
# merge_csv_positional('file1.csv', 'file2.csv', 0.5, 0.5, 'output.csv')

def print_best_f1(path):
    df = pd.read_csv(path)
    # Trova la riga con il massimo f1_score
    best_row = df.loc[df['f1_score'].idxmax()]

    # Stampa formato "colonna: valore"
    for col, val in best_row.items():
        print(f"{col}: {val}")


import matplotlib.pyplot as plt

def plot_multi_roc(files, labels, title):
    plt.figure(figsize=(8, 6))

    # Itera su file e label accoppiati
    for f, lbl in zip(files, labels):
        df = pd.read_csv(f).sort_values(by='fpr')
        plt.plot(df['fpr'], df['recall'], label=lbl)

    plt.plot([0, 1], [0, 1], 'k--', label='Random')
    plt.xlabel('FPR')
    plt.ylabel('Recall')
    plt.legend()
    plt.grid(True)
    plt.title(title)
    plt.show()


weights = {
    "actor": {
        "genome": 5,
        "gestao": 5
    },
    "hl": {
        "genome": 9,
        "gestao": 4
    },
    "ll": {
        "genome": 34,
        "gestao": 20
    }
}

for task in ["actor", "hl", "ll"]:
    file_names = []
    for prompting in [ShotPromptingMode.ZERO_SHOT, ShotPromptingMode.ONE_SHOT, ShotPromptingMode.FEW_SHOT]:

        file_name = f"{task}_{prompting}.csv"

        merge_csv_positional(f"../GENOME/{file_name}", f"../GESTAO/{file_name}", weights[task]["genome"], weights[task]["gestao"], f"output/{file_name}")

        print_best_f1(f"output/{file_name}")
        file_names.append(f"output/{file_name}")

    plot_multi_roc(file_names, ["Zero-shot", "One-shot", "Few-shot"], f"ROC for {task}")
